# %% [markdown]
# <h3>Income:</h3>
#
# 	Rental income = $2000/mth
# 		Laundry   =
# 		Storoage  =
# 		Misc      =
#
# 	Total Monthly income: $2,000
#
#
# <h3>Expenses:</h3>
#
# 		Tax =
# 		Insurance =
# 		Utilities(electric, water, sewer, gas) =
# 		user_enter =
# 		Lawn/Snow care =
# 		Vacancy(about 5% of total income or about) =
# 		Repairs =
# 		CapEx (big item issues) =
# 		Property Management =
# 		Mortgage =
#
# 	Total Monthly Expense = $1,600
#
# <h3>Cash Flow:</h3>
#
# 		Income – Expenses = Total Monthly Cash flow
#
# 	Total Monthly Cash flow = $390
#
# <h3>Annual Cash Flow:</h3>
#
# 		(Monthly Cash Flow) * 12
#
# 		Annual Cash Flow = $390 X 12 = $4,680
#
# <h3>Total Investment:</h3>
#
# 		Down Payment = $40,000
# 		Closing Cost = $3,000
# 		Rehab budget = $7,000
# 		Misc Other. =. $ 0
#
# 		Total Investment =  50,000
#
# <h3>Cash on Cash return (ROI) return on investment:</h3>
#
# 	Cash on Cash return = Annual cash flow / Total Investment.
# 							(4680/50,000)= 9.36%
#
#
#
#
# Overall Return (I want to know if I can find the equation to that)

# %%
#investment testing

class RentalROI:

    def __init__(self):
        self.investment_total = 0
        self.income_monthly = 0
        self.expense_monthly = 0
        self.cashFlow_monthly = 0
        self.cashFlow_yearly = 0
        self.roi = 0
        self.down_payment = 0
        self.closing_cost = 0
        self.rehab_budget = 0

    def __str__(self):
        return f"With an investment of ${self.investment_total}, a monthly income of {self.income_monthly}, monthly expenses of {self.expense_monthly}  your ROI is: {self.roi:.2f}"

    def __repr__(self):
        return f"<RentalROI | Monthly Income: ${self.income_monthly}, Monthly Expense: ${self.expense_monthly}, ROI: {self.roi:.2f}>"

    def input_investment(self):
            # Method to input down payment, closing cost, and rehab budget
            self.down_payment = float(input("Enter your down payment: "))
            self.closing_cost = float(input("Enter your closing cost: "))
            self.rehab_budget = float(input("Enter your rehab budget: "))
            self.investment_total = self.down_payment + self.closing_cost + self.rehab_budget

total_inv = RentalROI()
total_inv.input_investment()
print(total_inv)
# Out:
# With an investment of $20000.0, a monthly income of 0, monthly expenses of 0  your ROI is: 0.00

# %%
#Monthly income testing

class RentalROI:

    def __init__(self):
        self.investment_total = 0
        self.income_monthly = 0
        self.expense_monthly = 0
        self.cashFlow_monthly = 0
        self.cashFlow_yearly = 0
        self.roi = 0
        self.down_payment = 0
        self.closing_cost = 0
        self.rehab_budget = 0

    def __str__(self):
        return f"With an investment of ${self.investment_total}, a monthly income of {self.income_monthly}, monthly expenses of {self.expense_monthly}  your ROI is: {self.roi:.2f}%"

    def __repr__(self):
        return f"<RentalROI | Monthly Income: ${self.income_monthly}, Monthly Expense: ${self.expense_monthly}, ROI: {self.roi:.2f}>"
    
    def input_monthly_income(self):
        # Method to input rental income
        self.income_monthly = float(input("Enter the amount you charge for your rental property monthly: "))
        self.income_monthly += float(input("Enter the amount you charge for your laundry ammenities monthly: "))
        self.income_monthly += float(input("Enter the amount you charge for storage monthly: "))


# # #creating and instance of the RentalROI class
# rental_roi = RentalROI()
# #calling the input_monthly_income method so i can input income values
# rental_roi.input_monthly_income()
# #printing total for income_monthly based on my input
# print(f"Total monthly income is ${rental_roi.income_monthly}")

# %%
#Monthly expense testing

class RentalROI:

    def __init__(self):
        self.investment_total = 0
        self.income_monthly = 0
        self.expense_monthly = 0
        self.cashFlow_monthly = 0
        self.cashFlow_yearly = 0
        self.roi = 0
        self.down_payment = 0
        self.closing_cost = 0
        self.rehab_budget = 0

    def __str__(self):
        return f"With an investment of ${self.investment_total}, your ROI is: {self.roi:.2f}"

    def __repr__(self):
        return f"<RentalROI | Monthly Income: ${self.income_monthly}, Monthly Expense: ${self.expense_monthly}, ROI: {self.roi:.2f}>"
    
    def input_monthly_expenses(self):
        # Method to input expenses
        self.expense_monthly = float(input("Enter your monthly tax expense: "))
        self.expense_monthly += float(input("Enter your monthly insurance expense: "))
        self.expense_monthly += float(input("Enter your monthly HOA expense: "))
        self.expense_monthly += float(input("Enter your monthly lawn/snow care expense: "))
        self.expense_monthly += float(input("Enter your monthly repairs expense: "))
        self.expense_monthly += float(input("Enter your monthly CapEx (big item issues) expense: "))
        self.expense_monthly += float(input("Enter your monthly property management expense: "))
        self.expense_monthly += float(input("Enter your monthly mortgage expense: "))
        self.expense_monthly += (self.income_monthly * 0.05)  # Vacancy as 5% of income
        utility_expense = input("Do you have any utility expenses? (yes/no): ")
        if utility_expense.lower() == 'yes':
            self.expense_monthly += float(input("Enter your monthly electricity expense: "))
            self.expense_monthly += float(input("Enter your monthly water expense: "))
            self.expense_monthly += float(input("Enter your monthly sewer expense: "))
            self.expense_monthly += float(input("Enter your monthly garbage expense: "))

# rental_roi = RentalROI()
# rental_roi.input_monthly_expenses()
# print(f"Total monthly expense is ${rental_roi.expense_monthly}")
# print(rental_roi)
# Out:
# Total monthly expense is $850.0
# With an investment of $0, your ROI is: 0.00

# %%
#Tesing: for cash flow monthly, annually and ROI calc

class RentalROI:

    def __init__(self):
        self.investment_total = 21000
        self.income_monthly = 5000
        self.expense_monthly = 100
        self.cashFlow_monthly = 0
        self.cashFlow_yearly = 0
        self.roi = 0
        self.down_payment = 20000
        self.closing_cost = 1000
        self.rehab_budget = 0

    def __str__(self):
        return f"With an investment of ${self.investment_total}, your ROI is: {self.roi:.2f}"

    def __repr__(self):
        return f"<RentalROI | Monthly Income: ${self.income_monthly}, Monthly Expense: ${self.expense_monthly}, ROI: {self.roi:.2f}%>"
    

    def cash_flow_monthly(self):
            # Calculate the monthly cash flow
            self.cashFlow_monthly = self.income_monthly - self.expense_monthly

    def calculate_annual_cash_flow(self):
        # Calculate the annual cash flow
        self.cashFlow_yearly = (self.cashFlow_monthly * 12)

    def calculate_roi(self):
        # Calculate the ROI (Return on Investment)
        if self.investment_total != 0:
            self.roi = ((self.cashFlow_yearly / self.investment_total) * 100) 
            

            



roi_t = RentalROI()
roi_t.cash_flow_monthly()
roi_t.calculate_annual_cash_flow
roi_t.roi
print(roi_t)
print(roi_t.cash_flow_monthly)
print(roi_t.calculate_annual_cash_flow)
print(RentalROI.calculate_annual_cash_flow)
roi_t.cash_flow_monthly()
roi_t.cash_flow_monthly()
roi_t.calculate_annual_cash_flow()
roi_t.calculate_roi()
print(roi_t.cashFlow_monthly)
print(roi_t.cashFlow_yearly)

print(roi_t.calculate_roi)
# Out:
# With an investment of $21000, your ROI is: 0.00
# <bound method RentalROI.cash_flow_monthly of <RentalROI | Monthly Income: $5000, Monthly Expense: $100, ROI: 0.00%>>
# <bound method RentalROI.calculate_annual_cash_flow of <RentalROI | Monthly Income: $5000, Monthly Expense: $100, ROI: 0.00%>>
# <function RentalROI.calculate_annual_cash_flow at 0x1096b77e0>
# 4900
# 58800
# <bound method RentalROI.calculate_roi of <RentalROI | Monthly Income: $5000, Monthly Expense: $100, ROI: 280.00%>>

# %%
class RentalROI:

    def __init__(self):
        self.investment_total = 0
        self.income_monthly = 0
        self.expense_monthly = 0
        self.cashFlow_monthly = 0
        self.cashFlow_yearly = 0
        self.roi = 0
        self.down_payment = 0
        self.closing_cost = 0
        self.rehab_budget = 0

    def __str__(self):
        return f"With an investment of ${self.investment_total}, a monthly income of {self.income_monthly}, monthly expenses of {self.expense_monthly}  your ROI is: {self.roi:.2f}"

    def __repr__(self):
        return f"<RentalROI | Monthly Income: ${self.income_monthly}, Monthly Expense: ${self.expense_monthly}, ROI: {self.roi:.2f}>"
    

    def input_monthly_income(self):
        # Method to input rental income
        self.income_monthly = float(input("Enter the amount you charge for your rental property monthly: "))
        self.income_monthly += float(input("Enter the amount you charge for your laundry ammenities monthly: "))
        self.income_monthly += float(input("Enter the amount you charge for storage monthly: "))

    def input_monthly_expenses(self):
        # Method to input expenses
        self.expense_monthly =  (float(input("Enter your monthly tax expense: ")))
        self.expense_monthly += float(input("Enter your monthly insurance expense: "))
        self.expense_monthly += float(input("Enter your monthly HOA expense: "))
        self.expense_monthly += float(input("Enter your monthly lawn/snow care expense: "))
        self.expense_monthly += float(input("Enter your monthly repairs expense: "))
        self.expense_monthly += float(input("Enter your monthly CapEx (big item issues) expense: "))
        self.expense_monthly += float(input("Enter your monthly property management expense: "))
        self.expense_monthly += float(input("Enter your monthly mortgage expense: "))
        self.expense_monthly += (self.income_monthly * 0.05)  # Vacancy as 5% of income
        utility_expense = input("Do you have any utility expenses? (yes/no): ")
        if utility_expense.lower() == 'yes':
            self.expense_monthly += float(input("Enter your monthly electricity expense: "))
            self.expense_monthly += float(input("Enter your monthly water expense: "))
            self.expense_monthly += float(input("Enter your monthly sewer expense: "))
            self.expense_monthly += float(input("Enter your monthly garbage expense: "))

    def input_investment(self):
        # Method to input down payment, closing cost, and rehab budget
        self.down_payment = float(input("Enter your down payment: "))
        self.closing_cost = float(input("Enter your closing cost: "))
        self.rehab_budget = float(input("Enter your rehab budget: "))
        self.investment_total = self.down_payment + self.closing_cost + self.rehab_budget

    def cash_flow_monthly(self):
        # Calculate the monthly cash flow
        self.cashFlow_monthly = self.income_monthly - self.expense_monthly

    def calculate_annual_cash_flow(self):
        # Calculate the annual cash flow
        self.cashFlow_yearly = self.cashFlow_monthly * 12

    def calculate_roi(self):
        # Calculate the ROI (Return on Investment)
        if self.investment_total != 0:
            self.roi = (self.cashFlow_yearly / self.investment_total) * 100
        

    def rental_analysis(self):
        print("Lets figure see if you are better off with the stock market")
        self.input_monthly_income()
        self.input_monthly_expenses()
        self.input_investment()
        self.cash_flow_monthly()


# prop1 = RentalROI()
# prop1.rental_analysis

prop1 = RentalROI()
prop1.rental_analysis()
# Out:
# Lets figure see if you are better off with the stock market
